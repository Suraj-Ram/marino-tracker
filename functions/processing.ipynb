# %%
import pandas as pd
import numpy as np

raw_df = pd.read_csv("excel.csv")

# %%
raw_df.plot()
# Out:
# <AxesSubplot:>

# %%
raw_df["createdAt"] = pd.to_datetime(raw_df["createdAt"], unit="s")

# %%
import seaborn

seaborn.lineplot(data=raw_df, x="createdAt", y="marino_3rd_floor_weight/percentage")
# Out:
# <AxesSubplot:xlabel='createdAt', ylabel='marino_3rd_floor_weight/percentage'>
